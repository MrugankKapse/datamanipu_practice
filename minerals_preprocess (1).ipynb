# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\MRUGANK KAPSE\Downloads\Mines Datasheet-Tabelle 1.csv", sep=';')
df.columns = df.columns.str.strip()

def clean_numeric(val):
    if isinstance(val, str):
        val = val.replace(',', '.')
    try:
        return float(val)
    except:
        return np.nan

df['Latitude'] = df['Latitude'].apply(clean_numeric)
df['Longitude'] = df['Longitude'].apply(clean_numeric)
df['Production'] = df['Coal/ Lignite Production (MT) (2019-2020)'].apply(clean_numeric)
df['DummyWidth'] = df['Production'] * 0.1

print(df.head(10))
print(df.tail(10))
print(df.describe())
print(df.info())
print(df.shape)
print(df.isnull().sum())

df = df.drop_duplicates()
if 'SL No.' in df.columns:
    df.drop(columns=['SL No.'], inplace=True)

df['LatLongArea'] = df['Latitude'] * df['Longitude']
df['ProdArea'] = df['Production'] * df['DummyWidth']

lat_arr = df['Latitude'].to_numpy()
prod_arr = df['Production'].to_numpy()

print(np.mean(lat_arr))
print(np.std(prod_arr))
print(np.max(lat_arr))
print(np.min(prod_arr))

df['AreaSize'] = np.where(
    df['LatLongArea'] > df['LatLongArea'].mean(),
    'Large',
    'Small'
)

print(df.groupby('Type of Mine (OC/UG/Mixed)').mean(numeric_only=True))

print(
    df.groupby('Type of Mine (OC/UG/Mixed)').agg({
        'Latitude': ['mean', 'min', 'max'],
        'Production': ['mean', 'std']
    })
)

df_sorted = df.sort_values(by='Production', ascending=False)
print(df_sorted.head())

df['LatitudeNorm'] = (
    (df['Latitude'] - df['Latitude'].min()) /
    (df['Latitude'].max() - df['Latitude'].min())
)

large_area = df[df['LatLongArea'] > df['LatLongArea'].mean()]
print(large_area.head())

sample = df.sample(min(10, len(df)), random_state=1)
print(sample)

df_model = df.dropna(subset=['Latitude', 'Longitude', 'Production', 'Type of Mine (OC/UG/Mixed)']).copy()
Q1, Q3 = np.percentile(df_model['Production'], [25, 75])
IQR = Q3 - Q1
df_model = df_model[(df_model['Production'] >= (Q1 - 1.5 * IQR)) & (df_model['Production'] <= (Q3 + 1.5 * IQR))]
plt.figure(figsize=(10, 8))
sns.heatmap(df_model.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.savefig('correlation_heatmap.png')
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Latitude', y='Longitude', hue='Type of Mine (OC/UG/Mixed)')
plt.title("Latitude vs Longitude by Mine Type")
plt.savefig('scatter_plot.png')
# Out:
#    SL No. State/UT Name      District Name                       Mine Name  \
# 0       1   West Bengal  Paschim Bardhaman                Ningah Colliery
# 1       2   West Bengal  Paschim Bardhaman         Jhanjhara Project Colly
# 2       3   West Bengal  Paschim Bardhaman  MAOHUSUDANPUR 7 PIT &\nINCLINE
# 3       4   West Bengal  Paschim Bardhaman                PARASCOLE(EAST)
# 4       5   West Bengal  Paschim Bardhaman                PARASCOLE(WEST)
# 5       6   West Bengal  Paschim Bardhaman                       Jambad UG
# 6       7   West Bengal  Paschim Bardhaman                     Khas Kajora
# 7       8   West Bengal  Paschim Bardhaman                  Central Kajora
# 8       9   West Bengal  Paschim Bardhaman                      NABAKJORA
# 9      10   West Bengal  Paschim Bardhaman                 Satgram Project
#
#   Coal/ Lignite Production (MT) (2019-2020) Coal Mine Owner Name  \
# 0                                      0,01                  ECL
# 1                                       3,5                  ECL
# 2                                      0,04                  ECL
# 3                                       0,1                  ECL
# 4                                      0,07                  ECL
# 5                                      0,16                  ECL
# 6                                      0,17                  ECL
# 7                                      0,07                  ECL
# 8                                      0,06                  ECL
# 9                                      0,04                  ECL
#
#     Coal Mine Owner Full Name Coal/Lignite Govt Owned/Private  \
# 0  Eastern Coalfields Limited         Coal                  G
# 1  Eastern Coalfields Limited         Coal                  G
# 2  Eastern Coalfields Limited         Coal                  G
# 3  Eastern Coalfields Limited         Coal                  G
# 4  Eastern Coalfields Limited         Coal                  G
# 5  Eastern Coalfields Limited         Coal                  G
# 6  Eastern Coalfields Limited         Coal                  G
# 7  Eastern Coalfields Limited         Coal                  G
# 8  Eastern Coalfields Limited         Coal                  G
# 9  Eastern Coalfields Limited         Coal                  G
#
#   Type of Mine (OC/UG/Mixed)  Latitude  Longitude  \
# 0                         UG   23.6743    87.0333
# 1                         UG   23.6680    87.2963
# 2                         UG   23.6338    87.2037
# 3                         UG   23.6377    87.1951
# 4                         UG   23.6405    87.1855
# 5                         UG   23.6517    87.1734
# 6                         UG   23.6205    87.1926
# 7                         UG   23.6007    87.1874
# 8                         UG   23.6346    87.1793
# 9                         UG   23.6471    87.1594
#
#                                               Source  \
# 0  Google Maps: https://www.google.com/maps/place...
# 1  Google Maps: https://www.google.ca/maps/place/...
# 2  Google Maps: https://www.google.com/maps/place...
# 3  Google Maps: https://www.google.com/maps/place...
# 4  Google Maps: https://www.google.com/maps/place...
# 5  Google Maps: https://www.google.com/maps/place...
# 6  Google Maps: https://www.google.com/maps/place...
# 7  Google Maps: https://www.google.ca/maps/place/...
# 8  Google Maps: https://www.google.com/maps/place...
# 9  Google Maps: https://www.google.com/maps/place...
#
#                      Accuracy (exact vs approximate)  Unnamed: 14  Production  \
# 0                                              Exact          NaN        0.01
# 1                                              Exact          NaN        3.50
# 2   Approximate: Madhusudanpur Colliery Agent Office          NaN        0.04
# 3  Approximate: center coordinates of eastern Par...          NaN        0.10
# 4  Approximate: center coordinates of western Par...          NaN        0.07
# 5                                              Exact          NaN        0.16
# 6                    Approximate: center coordinates          NaN        0.17
# 7                            Approximate: PIN 713321          NaN        0.07
# 8                            Approximate: PIN 713384          NaN        0.06
# 9                                              Exact          NaN        0.04
#
#    DummyWidth
# 0       0.001
# 1       0.350
# 2       0.004
# 3       0.010
# 4       0.007
# 5       0.016
# 6       0.017
# 7       0.007
# 8       0.006
# 9       0.004
#      SL No. State/UT Name District Name           Mine Name  \
# 449     450    Telangana     Peddapalli  RG OC-III EXT PH-2
# 450     451    Telangana     Peddapalli             RG OC-2
# 451     452    Telangana     Peddapalli         RG OC-I LEP
# 452     453    Telangana     Peddapalli     Vakilpalli Mine
# 453     454    Telangana     Peddapalli         GDK 7 (LEP)
# 454     455    Telangana     Peddapalli         GDK 1&3 INC
# 455     456    Telangana     Peddapalli        GDK 2&2A INC
# 456     457    Telangana     Peddapalli           GDK 5 INC
# 457     458    Telangana     Peddapalli          GDK 11 INC
# 458     459    Telangana     Peddapalli          GDK 10 INC
#
#     Coal/ Lignite Production (MT) (2019-2020) Coal Mine Owner Name  \
# 449                                  2,562118                 SCCL
# 450                                  2,368628                 SCCL
# 451                                  4,634942                 SCCL
# 452                                   0,14763                 SCCL
# 453                                  0,198926                 SCCL
# 454                                  0,214798                 SCCL
# 455                                  0,283656                 SCCL
# 456                                  0,018202                 SCCL
# 457                                  0,804029                 SCCL
# 458                                  0,019551                 SCCL
#
#                     Coal Mine Owner Full Name Coal/Lignite Govt Owned/Private  \
# 449  The Singareni Collieries Company Limited         Coal                 SG
# 450  The Singareni Collieries Company Limited         Coal                 SG
# 451  The Singareni Collieries Company Limited         Coal                 SG
# 452  The Singareni Collieries Company Limited         Coal                 SG
# 453  The Singareni Collieries Company Limited         Coal                 SG
# 454  The Singareni Collieries Company Limited         Coal                 SG
# 455  The Singareni Collieries Company Limited         Coal                 SG
# 456  The Singareni Collieries Company Limited         Coal                 SG
# 457  The Singareni Collieries Company Limited         Coal                 SG
# 458  The Singareni Collieries Company Limited         Coal                 SG
#
#     Type of Mine (OC/UG/Mixed)  Latitude  Longitude  \
# 449                         OC   18.6976    79.5352
# 450                         OC   18.6782    79.5406
# 451                         OC   18.6683    79.5542
# 452                         UG   18.4014    79.3321
# 453                         UG   18.4316    79.3842
# 454                         UG   18.0452    79.3025
# 455                         UG   18.4221    79.3111
# 456                         UG   18.4545    79.3546
# 457                         UG   18.4161    79.3258
# 458                         UG   18.3915    79.3345
#
#                                                 Source  \
# 449  Pre-feasibility Report RG OC-III Expansion Min...
# 450  Google Maps: https://www.google.ca/maps/place/...
# 451  Pre-feasibility Report, Ramagundam Opencast-I ...
# 452  Prefeasibility report http://environmentcleara...
# 453  Prefeasibility report http://environmentcleara...
# 454  Environmental clearance https://scclmines.com/...
# 455  Brief Summary SCCL: http://environmentclearanc...
# 456  Brief Summary SCCL: http://environmentclearanc...
# 457  Environmental clearance https://scclmines.com/...
# 458  Environmental Clearance https://scclmines.com/...
#
#                        Accuracy (exact vs approximate)  Unnamed: 14  \
# 449                                              Exact          NaN
# 450  Approximate: coordinates of building near RG-2...          NaN
# 451                                              Exact          NaN
# 452                                              Exact          NaN
# 453                                              Exact          NaN
# 454                                              Exact          NaN
# 455                                              Exact          NaN
# 456                                              Exact          NaN
# 457                                              Exact          NaN
# 458                                              Exact          NaN
#
#      Production  DummyWidth
# 449    2.562118    0.256212
# 450    2.368628    0.236863
# 451    4.634942    0.463494
# 452    0.147630    0.014763
# 453    0.198926    0.019893
# 454    0.214798    0.021480
# 455    0.283656    0.028366
# 456    0.018202    0.001820
# 457    0.804029    0.080403
# 458    0.019551    0.001955
#            SL No.    Latitude   Longitude  Unnamed: 14  Production  DummyWidth
# count  459.000000  459.000000  459.000000          0.0   459.00000  459.000000
# mean   230.000000   22.291776   82.954549          NaN     1.68512    0.168512
# std    132.646146    2.173549    3.858629          NaN     4.45221    0.445221
# min      1.000000   11.520268   68.530000          NaN     0.00000    0.000000
# 25%    115.500000   21.077450   79.502700          NaN     0.07000    0.007000
# 50%    230.000000   23.290000   83.085600          NaN     0.28000    0.028000
# 75%    344.500000   23.733000   86.352845          NaN     1.20000    0.120000
# max    459.000000   27.523140   95.855600          NaN    45.00000    4.500000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 17 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   SL No.                                     459 non-null    int64
#  1   State/UT Name                              459 non-null    object
#  2   District Name                              459 non-null    object
#  3   Mine Name                                  459 non-null    object
#  4   Coal/ Lignite Production (MT) (2019-2020)  459 non-null    object
#  5   Coal Mine Owner Name                       459 non-null    object
#  6   Coal Mine Owner Full Name                  448 non-null    object
#  7   Coal/Lignite                               459 non-null    object
#  8   Govt Owned/Private                         459 non-null    object
#  9   Type of Mine (OC/UG/Mixed)                 459 non-null    object
#  10  Latitude                                   459 non-null    float64
#  11  Longitude                                  459 non-null    float64
#  12  Source                                     459 non-null    object
#  13  Accuracy (exact vs approximate)            459 non-null    object
#  14  Unnamed: 14                                0 non-null      float64
#  15  Production                                 459 non-null    float64
#  16  DummyWidth                                 459 non-null    float64
# dtypes: float64(5), int64(1), object(11)
# memory usage: 61.1+ KB
# None
# (459, 17)
# SL No.                                         0
# State/UT Name                                  0
# District Name                                  0
# Mine Name                                      0
# Coal/ Lignite Production (MT) (2019-2020)      0
# Coal Mine Owner Name                           0
# Coal Mine Owner Full Name                     11
# Coal/Lignite                                   0
# Govt Owned/Private                             0
# Type of Mine (OC/UG/Mixed)                     0
# Latitude                                       0
# Longitude                                      0
# Source                                         0
# Accuracy (exact vs approximate)                0
# Unnamed: 14                                  459
# Production                                     0
# DummyWidth                                     0
# dtype: int64
# 22.291776406296265
# 4.447357939895214
# 27.52314
# 0.0
#                              Latitude  Longitude  Unnamed: 14  Production  \
# Type of Mine (OC/UG/Mixed)
# Mixed                       23.565342  85.947846          NaN    0.820600
# OC                          22.123756  82.459814          NaN    2.816617
# UG                          22.387634  83.319500          NaN    0.196743
#
#                             DummyWidth  LatLongArea  ProdArea
# Type of Mine (OC/UG/Mixed)
# Mixed                         0.082060  2026.551662  0.168341
# OC                            0.281662  1828.211141  4.031050
# UG                            0.019674  1869.741316  0.015733
#                              Latitude                      Production  \
#                                  mean        min       max       mean
# Type of Mine (OC/UG/Mixed)
# Mixed                       23.565342  21.895785  23.80790   0.820600
# OC                          22.123756  11.520268  27.52314   2.816617
# UG                          22.387634  17.479300  27.30390   0.196743
#
#
#                                  std
# Type of Mine (OC/UG/Mixed)
# Mixed                       1.031108
# OC                          5.701240
# UG                          0.345359
#     State/UT Name District Name     Mine Name  \
# 311  Chhattisgarh         Korba      GEVRA OC
# 310  Chhattisgarh         Korba      KUSMUNDA
# 360        Orissa        Angul   BHUBANESWARI
# 312  Chhattisgarh         Korba         DIPKA
# 367        Orissa    Jharsuguda     LAKHANPUR
#
#     Coal/ Lignite Production (MT) (2019-2020) Coal Mine Owner Name  \
# 311                                        45                 SECL
# 310                                     42,33                 SECL
# 360                                        28                  MCL
# 312                                     25,18                 SECL
# 367                                        21                  MCL
#
#              Coal Mine Owner Full Name Coal/Lignite Govt Owned/Private  \
# 311  South Eastern Coalfields Limited          Coal                  G
# 310  South Eastern Coalfields Limited          Coal                  G
# 360        Mahanadi Coalfields Limited         Coal                  G
# 312  South Eastern Coalfields Limited          Coal                  G
# 367        Mahanadi Coalfields Limited         Coal                  G
#
#     Type of Mine (OC/UG/Mixed)  Latitude  Longitude  \
# 311                         OC   22.3308    82.5958
# 310                         OC   22.3067    82.6732
# 360                         OC   20.9725    85.1732
# 312                         OC   22.3225    82.5363
# 367                         OC   21.7451    83.8401
#
#                                                 Source  \
# 311  Project Report for Gevra OC Expansion: http://...
# 310  Environmental Clearance, Expansion of Kusmunda...
# 360  Application for Prior Environmental Clearance ...
# 312  EIA & EMP for Peak Capacity of Existing, Appro...
# 367  Application for Prior Environmental Clearance ...
#
#     Accuracy (exact vs approximate)  Unnamed: 14  Production  DummyWidth  \
# 311                           Exact          NaN       45.00       4.500
# 310                           Exact          NaN       42.33       4.233
# 360                           Exact          NaN       28.00       2.800
# 312                           Exact          NaN       25.18       2.518
# 367                           Exact          NaN       21.00       2.100
#
#      LatLongArea   ProdArea AreaSize
# 311  1844.430291  202.50000    Small
# 310  1844.166270  179.18289    Small
# 360  1786.294937   78.40000    Small
# 312  1842.416557   63.40324    Small
# 367  1823.111359   44.10000    Small
#   State/UT Name      District Name                       Mine Name  \
# 0   West Bengal  Paschim Bardhaman                Ningah Colliery
# 1   West Bengal  Paschim Bardhaman         Jhanjhara Project Colly
# 2   West Bengal  Paschim Bardhaman  MAOHUSUDANPUR 7 PIT &\nINCLINE
# 3   West Bengal  Paschim Bardhaman                PARASCOLE(EAST)
# 4   West Bengal  Paschim Bardhaman                PARASCOLE(WEST)
#
#   Coal/ Lignite Production (MT) (2019-2020) Coal Mine Owner Name  \
# 0                                      0,01                  ECL
# 1                                       3,5                  ECL
# 2                                      0,04                  ECL
# 3                                       0,1                  ECL
# 4                                      0,07                  ECL
#
#     Coal Mine Owner Full Name Coal/Lignite Govt Owned/Private  \
# 0  Eastern Coalfields Limited         Coal                  G
# 1  Eastern Coalfields Limited         Coal                  G
# 2  Eastern Coalfields Limited         Coal                  G
# 3  Eastern Coalfields Limited         Coal                  G
# 4  Eastern Coalfields Limited         Coal                  G
#
#   Type of Mine (OC/UG/Mixed)  Latitude  Longitude  \
# 0                         UG   23.6743    87.0333
# 1                         UG   23.6680    87.2963
# 2                         UG   23.6338    87.2037
# 3                         UG   23.6377    87.1951
# 4                         UG   23.6405    87.1855
#
#                                               Source  \
# 0  Google Maps: https://www.google.com/maps/place...
# 1  Google Maps: https://www.google.ca/maps/place/...
# 2  Google Maps: https://www.google.com/maps/place...
# 3  Google Maps: https://www.google.com/maps/place...
# 4  Google Maps: https://www.google.com/maps/place...
#
#                      Accuracy (exact vs approximate)  Unnamed: 14  Production  \
# 0                                              Exact          NaN        0.01
# 1                                              Exact          NaN        3.50
# 2   Approximate: Madhusudanpur Colliery Agent Office          NaN        0.04
# 3  Approximate: center coordinates of eastern Par...          NaN        0.10
# 4  Approximate: center coordinates of western Par...          NaN        0.07
#
#    DummyWidth  LatLongArea  ProdArea AreaSize  LatitudeNorm
# 0       0.001  2060.452454   0.00001    Large      0.759491
# 1       0.350  2066.128828   1.22500    Large      0.759097
# 2       0.004  2060.954805   0.00016    Large      0.756960
# 3       0.010  2061.091615   0.00100    Large      0.757204
# 4       0.007  2061.108813   0.00049    Large      0.757379
#       State/UT Name         District Name      Mine Name  \
# 67      West Bengal               Purulia      PARBELIA
# 146      Jharkhand             Hazaribagh       GIDI 'A'
# 324  Madhya Pradesh               Anuppur  RAJNAGAR R.O.
# 436      Telangana             Mancherial      SRP 1 INC
# 224    Maharashtra               Yavatmal     PIMPALGAON
# 283    Chhattisgarh               Surguja      KUMDA 7&8
# 382           Assam              Tinsukia          Tikak
# 289    Chhattisgarh               Surguja         AMGAON
# 404      Telangana   Bhadradri Kothagudem      JVR OC-II
# 92       Jharkhand               Dhanbad       BHAGABAND
#
#     Coal/ Lignite Production (MT) (2019-2020) Coal Mine Owner Name  \
# 67                                       0,06                  ECL
# 146                                      0,11                  CCL
# 324                                      0,27                 SECL
# 436                                  0,161502                 SCCL
# 224                                         0                  WCL
# 283                                      0,08                 SECL
# 382                                      0,07                  NEC
# 289                                         0                 SECL
# 404                                  4,828857                 SCCL
# 92                                       0,02                 BCCL
#
#                     Coal Mine Owner Full Name Coal/Lignite Govt Owned/Private  \
# 67                 Eastern Coalfields Limited         Coal                  G
# 146                Central Coalfields Limited         Coal                  G
# 324         South Eastern Coalfields Limited          Coal                  G
# 436  The Singareni Collieries Company Limited         Coal                 SG
# 224                Western Coalfields Limited         Coal                  G
# 283         South Eastern Coalfields Limited          Coal                  G
# 382                  North Eastern Coalfields         Coal                  G
# 289         South Eastern Coalfields Limited          Coal                  G
# 404  The Singareni Collieries Company Limited         Coal                 SG
# 92                 Bharat Coking Coal Limited         Coal                  G
#
#     Type of Mine (OC/UG/Mixed)   Latitude  Longitude  \
# 67                          UG  23.673300  86.825700
# 146                         OC  23.683300  85.358300
# 324                         UG  23.189700  82.132000
# 436                         UG  18.857600  79.499400
# 224                         OC  20.045800  79.041700
# 283                         UG  23.207400  83.005600
# 382                         OC  27.283600  95.733400
# 289                         OC  23.136700  82.830000
# 404                         OC  17.095459  80.454338
# 92                          UG  23.741600  86.386100
#
#                                                 Source  \
# 67   Google Maps: https://www.google.com/maps/place...
# 146  Environmental Statement of Gidi 'A' OCP for 20...
# 324  Google Maps: https://www.google.ca/maps/place/...
# 436  Google Maps: https://www.google.ca/maps/place/...
# 224  2017 WCL Land Restoration/Reclamation Monitori...
# 283  Google Maps: https://www.google.com/maps/place...
# 382  Google Maps: https://www.google.ca/maps/place/...
# 289  Project Report for Amgaon Opencast Project: ht...
# 404  Public hearing https://tspcb.cgg.gov.in/public...
# 92   Google Maps: https://www.google.com/maps/place...
#
#                        Accuracy (exact vs approximate)  Unnamed: 14  \
# 67                             Approximate: PIN 713324          NaN
# 146                                              Exact          NaN
# 324  Approximate: coordinates of nearby hospital in...          NaN
# 436                                              Exact          NaN
# 224                                              Exact          NaN
# 283      Approximate: coordinates of hospital in Kumda          NaN
# 382                                              Exact          NaN
# 289                                              Exact          NaN
# 404                                             Approx          NaN
# 92                                               Exact          NaN
#
#      Production  DummyWidth  LatLongArea  ProdArea AreaSize  LatitudeNorm
# 67     0.060000    0.006000  2055.450844  0.000360    Large      0.759428
# 146    0.110000    0.011000  2021.566226  0.001210    Large      0.760053
# 324    0.270000    0.027000  1904.616440  0.007290    Large      0.729209
# 436    0.161502    0.016150  1499.167885  0.002608    Small      0.458501
# 224    0.000000    0.000000  1584.454110  0.000000    Small      0.532750
# 283    0.080000    0.008000  1926.344161  0.000640    Large      0.730315
# 382    0.070000    0.007000  2611.951792  0.000490    Large      0.985031
# 289    0.000000    0.000000  1916.412861  0.000000    Large      0.725897
# 404    4.828857    0.482886  1375.403837  2.331786    Small      0.348387
# 92     0.020000    0.002000  2050.944232  0.000040    Large      0.763696
